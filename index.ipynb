# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.
from bs4 import BeautifulSoup
from datetime import datetime as dt
import pandas as pd
import requests

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Testing scrape
url = 'https://www.residentadvisor.net/events/us/newyork'
#url = 'https://www.residentadvisor.net/events/us/virginia/month/2020-01-04'
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
# All the information about events is contained in this section:
events_container = soup.find('ul', {'id':"items"})
print(events_container.prettify())
# Out:
# <ul class="list" id="items">
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=5">
#     <span>
#      Sun, 05 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1363143#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <a href="/events/1363143">
#     <img height="76" src="/images/events/flyer/2020/1/us-0105-1363143-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1363143" itemprop="url" title="Event details of Weird Science n.17 with Ron Morelli, L.Sangre, Maroje T">
#       Weird Science n.17 with Ron Morelli, L.Sangre, Maroje T
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=121281">
#        Magick City
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Ron Morelli, L.Sangre, Maroje T
#     </div>
#     <p class="attending">
#      <span>
#       49
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1356435#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <a href="/events/1356435">
#     <img height="76" src="/images/events/flyer/2020/1/us-0105-1356435-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1356435" itemprop="url" title="Event details of Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Funday Brunch Party">
#       Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Funday Brunch Party
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=29869">
#        Taj Lounge
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      TOP NYC DJS
#     </div>
#     <p class="attending">
#      <span>
#       1
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <a href="/events/1363594">
#     <img height="76" src="/images/events/flyer/2020/1/us-0105-1363594-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1363594" itemprop="url" title="Event details of Zephyr Ann Bday with Paul Nickerson, Ivan Monegro, Mo Yasin">
#       Zephyr Ann Bday with Paul Nickerson, Ivan Monegro, Mo Yasin
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=164270">
#        public records
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Paul Nickerson, Ivan Monegro, Mo Yasin
#     </div>
#     <p class="attending">
#      <span>
#       8
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <a href="/events/1366337">
#     <img height="76" src="/images/events/flyer/2020/1/us-0105-1366337-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366337" itemprop="url" title="Event details of Sunday Soiree: Tony Paniro and HŸPNØTÏX">
#       Sunday Soiree: Tony Paniro and HŸPNØTÏX
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75374">
#        TBA Brooklyn
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Tony Paniro, HŸPNØTÏX
#     </div>
#     <p class="attending">
#      <span>
#       8
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1354636" itemprop="url" title="Event details of The Office presents: Anti-Social Takeover">
#       The Office presents: Anti-Social Takeover
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        TBA - Brooklyn
#       </span>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-05T00:00" itemprop="startDate">
#      2020-01-05T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367367" itemprop="url" title="Event details of Cotton / Motiv-A / Extol / January">
#       Cotton / Motiv-A / Extol / January
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=71292">
#        Bossa Nova Civic Club
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=6">
#     <span>
#      Mon, 06 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-06T00:00" itemprop="startDate">
#      2020-01-06T00:00
#     </time>
#    </span>
#    <a href="/events/1354615">
#     <img height="76" src="/images/events/flyer/2020/1/us-0106-1354615-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1354615" itemprop="url" title="Event details of The Office presents: Shhh Music By: Mike Nervous">
#       The Office presents: Shhh Music By: Mike Nervous
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        TBA - Brooklyn
#       </span>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Mike Nervous
#     </div>
#     <p class="attending">
#      <span>
#       4
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-06T00:00" itemprop="startDate">
#      2020-01-06T00:00
#     </time>
#    </span>
#    <a href="/events/1365706">
#     <img height="76" src="/images/events/flyer/2020/1/us-0106-1365706-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1365706" itemprop="url" title="Event details of Fermented Frequency">
#       Fermented Frequency
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=71292">
#        Bossa Nova Civic Club
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Love Letters, Joselo, POSI-TRACK
#     </div>
#     <p class="attending">
#      <span>
#       3
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-06T00:00" itemprop="startDate">
#      2020-01-06T00:00
#     </time>
#    </span>
#    <a href="/events/1368600">
#     <img height="76" src="/images/events/flyer/2020/1/us-0106-1368600-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368600" itemprop="url" title="Event details of Industry Night with Special Guests">
#       Industry Night with Special Guests
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=145350">
#        Rose Gold
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      TBA
#     </div>
#     <p class="attending">
#      <span>
#       1
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-06T00:00" itemprop="startDate">
#      2020-01-06T00:00
#     </time>
#    </span>
#    <a href="/events/1368742">
#     <img height="76" src="/images/events/flyer/2020/1/us-0106-1368742-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368742" itemprop="url" title="Event details of Jamais Vu presents Sheepshead, Feverdream, Serrian">
#       Jamais Vu presents Sheepshead, Feverdream, Serrian
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=128789">
#        Jupiter Disco
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Sheepshead, Feverdream, Serrian
#     </div>
#     <p class="attending">
#      <span>
#       1
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=7">
#     <span>
#      Tue, 07 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-07T00:00" itemprop="startDate">
#      2020-01-07T00:00
#     </time>
#    </span>
#    <a href="/events/1359922">
#     <img height="76" src="/images/events/flyer/2020/1/us-0107-1359922-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1359922" itemprop="url" title="Event details of Despacito with Dynoman, The Space Wanderer &amp; Amelia Holt">
#       Despacito with Dynoman, The Space Wanderer &amp; Amelia Holt
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=128789">
#        Jupiter Disco
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Dynoman, The Space Wanderer, Amelia Holt
#     </div>
#     <p class="attending">
#      <span>
#       8
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-07T00:00" itemprop="startDate">
#      2020-01-07T00:00
#     </time>
#    </span>
#    <a href="/events/1366393">
#     <img height="76" src="/images/events/flyer/2020/1/us-0107-1366393-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366393" itemprop="url" title="Event details of Dumbtrax with Brian Best, Mike Terra, Zeni Karpuzi">
#       Dumbtrax with Brian Best, Mike Terra, Zeni Karpuzi
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75374">
#        TBA Brooklyn
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Brian Best, Mike Terra, Zeni Karpuzi
#     </div>
#     <p class="attending">
#      <span>
#       7
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-07T00:00" itemprop="startDate">
#      2020-01-07T00:00
#     </time>
#    </span>
#    <a href="/events/1366849">
#     <img height="76" src="/images/events/flyer/2020/1/us-0107-1366849-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366849" itemprop="url" title="Event details of Tuesday Tropical: K.Mal Nite with Disco Bogotá + Feel Free NYC">
#       Tuesday Tropical: K.Mal Nite with Disco Bogotá + Feel Free NYC
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=157710">
#        Kinfolk 90
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      K.Mal, Disco Bogotá, Grand Atrium, Buskko, Off Brand
#     </div>
#     <p class="attending">
#      <span>
#       2
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-07T00:00" itemprop="startDate">
#      2020-01-07T00:00
#     </time>
#    </span>
#    <a href="/events/1366616">
#     <img height="76" src="/images/events/flyer/2020/1/us-0107-1366616-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366616" itemprop="url" title="Event details of Feel Real presents Good Music Tuesdays">
#       Feel Real presents Good Music Tuesdays
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=117093">
#        Rumpus Room
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      DJ Disciple
#     </div>
#     <p class="attending">
#      <span>
#       1
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-07T00:00" itemprop="startDate">
#      2020-01-07T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367396" itemprop="url" title="Event details of Tournament Tuesdays with Trash Panda Qc (DJ Set)">
#       Tournament Tuesdays with Trash Panda Qc (DJ Set)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=168479">
#        Wonderville
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=8">
#     <span>
#      Wed, 08 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-08T00:00" itemprop="startDate">
#      2020-01-08T00:00
#     </time>
#    </span>
#    <a href="/events/1366391">
#     <img height="76" src="/images/events/flyer/2020/1/us-0108-1366391-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366391" itemprop="url" title="Event details of Ūndisxile - Sebjara Juancep / Batuz / Mark Dumitrescu">
#       Ūndisxile - Sebjara Juancep / Batuz / Mark Dumitrescu
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75374">
#        TBA Brooklyn
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Sebjara, Juancep, Batuz, Mark Dumitrescu
#     </div>
#     <p class="attending">
#      <span>
#       6
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-08T00:00" itemprop="startDate">
#      2020-01-08T00:00
#     </time>
#    </span>
#    <a href="/events/1367207">
#     <img height="76" src="/images/events/flyer/dj/renata-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367207" itemprop="url" title="Event details of Distrikt1 with Melania, Renata">
#       Distrikt1 with Melania, Renata
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=71292">
#        Bossa Nova Civic Club
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Melania, Renata, Ne/Re/A, Lychee
#     </div>
#     <p class="attending">
#      <span>
#       6
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-08T00:00" itemprop="startDate">
#      2020-01-08T00:00
#     </time>
#    </span>
#    <a href="/events/1367640">
#     <img height="76" src="/images/events/flyer/2020/1/us-0108-1367640-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367640" itemprop="url" title="Event details of Effervescence // Chung, Comfort Zone, Play DJ, Downloadable Content">
#       Effervescence // Chung, Comfort Zone, Play DJ, Downloadable Content
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=141852">
#        Mood Ring
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Chung, Comfort Zone, Play DJ, Downloadable Content
#     </div>
#     <p class="attending">
#      <span>
#       4
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=9">
#     <span>
#      Thu, 09 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1355570#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-09T00:00" itemprop="startDate">
#      2020-01-09T00:00
#     </time>
#    </span>
#    <a href="/events/1355570">
#     <img height="76" src="/images/events/flyer/2020/1/us-0109-1355570-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1355570" itemprop="url" title="Event details of Darker Than Wax with Lefto Plus Tonight's Special with Bosq">
#       Darker Than Wax with Lefto Plus Tonight's Special with Bosq
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=97606">
#        Good Room
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Good Room presents, Darker Than Wax with special guest LEFTO, Marco Weibel &amp; Mawkus, Tonight's Special in the Bad Room, with Bosq, Chakana Inca and DIMS
#     </div>
#     <p class="attending">
#      <span>
#       9
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1366827#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-09T00:00" itemprop="startDate">
#      2020-01-09T00:00
#     </time>
#    </span>
#    <a href="/events/1366827">
#     <img height="76" src="/images/events/flyer/2020/1/us-0109-1366827-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366827" itemprop="url" title="Event details of Deep Root Sessions At Public Arts with Mighty Mouse">
#       Deep Root Sessions At Public Arts with Mighty Mouse
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139613">
#        Public Arts
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Mighty Mouse
#     </div>
#     <p class="attending">
#      <span>
#       2
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-09T00:00" itemprop="startDate">
#      2020-01-09T00:00
#     </time>
#    </span>
#    <a href="/events/1366851">
#     <img height="76" src="/images/events/flyer/2020/1/us-0109-1366851-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366851" itemprop="url" title="Event details of Gusto_invites with Simon Heyliger, Nick Rodrigues">
#       Gusto_invites with Simon Heyliger, Nick Rodrigues
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75374">
#        TBA Brooklyn
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Simon Heyliger, Nick Rodrigues
#     </div>
#     <p class="attending">
#      <span>
#       7
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-09T00:00" itemprop="startDate">
#      2020-01-09T00:00
#     </time>
#    </span>
#    <a href="/events/1368233">
#     <img height="76" src="/images/events/flyer/2020/1/us-0109-1368233-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368233" itemprop="url" title="Event details of Penthouse Edits Vol. 2 Release Party">
#       Penthouse Edits Vol. 2 Release Party
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=141852">
#        Mood Ring
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Phoneg1rl, Fine Touch, Malik Hendricks, Khalil Lajmi
#     </div>
#     <p class="attending">
#      <span>
#       1
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=10">
#     <span>
#      Fri, 10 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1349333#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1349333">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1349333-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1349333" itemprop="url" title="Event details of Friday: Working Women and DJ Marcelle">
#       Friday: Working Women and DJ Marcelle
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=105873">
#        Nowadays
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Working Women, DJ Marcelle
#     </div>
#     <p class="attending">
#      <span>
#       100
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1358784#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1358784">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1358784-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1358784" itemprop="url" title="Event details of Planetarium">
#       Planetarium
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        TBA - Brooklyn
#       </span>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      stud1nt, Justin Carter, Eamon Harkin, YOKUBARI live
#     </div>
#     <p class="attending">
#      <span>
#       73
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1359516#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1359516">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1359516-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1359516" itemprop="url" title="Event details of Robag Wruhme (All Night)">
#       Robag Wruhme (All Night)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=160440">
#        Lost Circus at Avant Gardner
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Robag Wruhme
#     </div>
#     <p class="attending">
#      <span>
#       64
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item pick clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1338219#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1338219">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1338219-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1338219" itemprop="url" title="Event details of The Selectors present Taimur's Birthday Bash with Luca Lozano (Klasse Wrecks)">
#       The Selectors present Taimur's Birthday Bash with Luca Lozano (Klasse Wrecks)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=164270">
#        public records
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Luca Lozano, Taimur, ALL NIGHT LONG
#     </div>
#     <p class="attending">
#      <span>
#       55
#      </span>
#      Attending
#     </p>
#     <div class="pick-intro">
#      <div class="pick-icon">
#       RA Pick
#      </div>
#      Berlin's Luca Lozano has been playing genres such as hardcore, breakbeat, acid house, newbeat, bleep, and jungle since before it was cool—and he does it with a '90s flair and personality that few can match. Don't miss this one.
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1351456#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1351456">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1351456-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1351456" itemprop="url" title="Event details of The Knocks and Friends Featuring: Mat Zo and The Knocks (DJ Set)">
#       The Knocks and Friends Featuring: Mat Zo and The Knocks (DJ Set)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      HALL, The Knocks and Friends Featuring, └ Mat Zo, └ └ The Knocks
#     </div>
#     <p class="attending">
#      <span>
#       42
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1357498#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1357498">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1357498-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1357498" itemprop="url" title="Event details of Veronica Vasicka / Hieroglyphic Being Live / John Barera">
#       Veronica Vasicka / Hieroglyphic Being Live / John Barera
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=165976">
#        BASEMENT
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Veronica Vasicka, Hieroglyphic Being, John Barera
#     </div>
#     <p class="attending">
#      <span>
#       33
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1367307#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1367307">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1367307-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367307" itemprop="url" title="Event details of HARDER SPRKLBB Bill Sanders (Berlin)">
#       HARDER SPRKLBB Bill Sanders (Berlin)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=159838">
#        3 Dollar Bill
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      SPRKLBB, Bill Sanders
#     </div>
#     <p class="attending">
#      <span>
#       32
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item pick clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1359983#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <a href="/events/1359983">
#     <img height="76" src="/images/events/flyer/2020/1/us-0110-1359983-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1359983" itemprop="url" title="Event details of Lost Soul Enterprises 8th Anniversary with December (Live), Mozhgan, Emma DJ, Enrique (Live)">
#       Lost Soul Enterprises 8th Anniversary with December (Live), Mozhgan, Emma DJ, Enrique (Live)
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=97606">
#        Good Room
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      December, Mozhgan, Emma DJ, Enrique, L.Sangre, Heidi Sabertooth, R Gamble
#     </div>
#     <p class="attending">
#      <span>
#       28
#      </span>
#      Attending
#     </p>
#     <div class="pick-intro">
#      <div class="pick-icon">
#       RA Pick
#      </div>
#      Fusion Mes Couilles co-head Emma DJ represents the hardest and most peculiar sounds of the Paris party. Whether he's playing electro, hard dance or rumbling techno, his sound hits his unsuspecting audiences like a brick.
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1361439#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1361439" itemprop="url" title="Event details of Nails &amp; Wax presents: Reka and Roman">
#       Nails &amp; Wax presents: Reka and Roman
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=170479">
#        The Sultan Room
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1368159#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368159" itemprop="url" title="Event details of Access presents Drumcell: Luis Flores: Deraout: Mike Melidosian">
#       Access presents Drumcell: Luis Flores: Deraout: Mike Melidosian
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=116788">
#        Quantum
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1360634#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1360634" itemprop="url" title="Event details of Fomo 5 Year Anniversary with Eli Escobar, Darling Chuck, Sunny Cheeba &amp; More">
#       Fomo 5 Year Anniversary with Eli Escobar, Darling Chuck, Sunny Cheeba &amp; More
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1353602#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1353602" itemprop="url" title="Event details of Pandamonium Journeys: Greg Downey">
#       Pandamonium Journeys: Greg Downey
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=119168">
#        Bogart House
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1367215" itemprop="url" title="Event details of Easy with Wilki, Jordan James &amp; Isa">
#       Easy with Wilki, Jordan James &amp; Isa
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=36873">
#        Le Bain
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1354623" itemprop="url" title="Event details of The Office presents: Red Light Secrets Music By: Essi">
#       The Office presents: Red Light Secrets Music By: Essi
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        TBA - Brooklyn
#       </span>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1364061" itemprop="url" title="Event details of The Assembly with AG, Ducci, Tone Troy">
#       The Assembly with AG, Ducci, Tone Troy
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-10T00:00" itemprop="startDate">
#      2020-01-10T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368872" itemprop="url" title="Event details of Dreamland presents Oveous">
#       Dreamland presents Oveous
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=160842">
#        Good Behavior (at MADE Hotel)
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
#  <li>
#   <p class="eventDate date">
#    <a href="/events.aspx?ai=8&amp;v=day&amp;mn=1&amp;yr=2020&amp;dy=11">
#     <span>
#      Sat, 11 Jan 2020 /
#     </span>
#    </a>
#   </p>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1357501#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1357501">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1357501-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1357501" itemprop="url" title="Event details of Fist with Perc / Baby Blue / Word of Command / DJ Clone">
#       Fist with Perc / Baby Blue / Word of Command / DJ Clone
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=165976">
#        BASEMENT
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Perc, Baby Blue, Word of Command, DJ Clone
#     </div>
#     <p class="attending">
#      <span>
#       94
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1366608#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1366608">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1366608-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366608" itemprop="url" title="Event details of The Carry Nation January 2020">
#       The Carry Nation January 2020
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=97606">
#        Good Room
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      The Carry Nation, Father Figure, Heidy.P
#     </div>
#     <p class="attending">
#      <span>
#       41
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item pick clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1347720#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1347720">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1347720-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1347720" itemprop="url" title="Event details of Juan Maclean (DJ Set), Solar, Ash Lauryn">
#       Juan Maclean (DJ Set), Solar, Ash Lauryn
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      HALL, └ Juan MacLean, └ └ Solar, └ └ └ Ash Lauryn
#     </div>
#     <p class="attending">
#      <span>
#       26
#      </span>
#      Attending
#     </p>
#     <div class="pick-intro">
#      <div class="pick-icon">
#       RA Pick
#      </div>
#      Bay Area resident Solar culls psychedelic, weirdo beats that feel more like the haziest scenes from a soundtrack than a two-deck DJ set.
#     </div>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1349343#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1349343">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1349343-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1349343" itemprop="url" title="Event details of Saturday: Umfang and OK Williams">
#       Saturday: Umfang and OK Williams
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=105873">
#        Nowadays
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Umfang, OK Williams
#     </div>
#     <p class="attending">
#      <span>
#       25
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1364167#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1364167">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1364167-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1364167" itemprop="url" title="Event details of The Scene: One Year Anniversary">
#       The Scene: One Year Anniversary
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=156758">
#        Eris
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Wassu, Aquariox
#     </div>
#     <p class="attending">
#      <span>
#       6
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1366335#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1366335">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1366335-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366335" itemprop="url" title="Event details of Studio 34 with Greg Paulus, Pjay, Gio Gulez, 34th Street John">
#       Studio 34 with Greg Paulus, Pjay, Gio Gulez, 34th Street John
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75374">
#        TBA Brooklyn
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Greg Paulus, PJay, 34th Street John, Gio Gulez
#     </div>
#     <p class="attending">
#      <span>
#       6
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <a href="/events/1347722#tickets">
#     <img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/>
#    </a>
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1347722">
#     <img height="76" src="/images/events/flyer/2020/1/us-0114-1347722-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1347722" itemprop="url" title="Event details of Pleasure Jams feat. Razor-N-Tape">
#       Pleasure Jams feat. Razor-N-Tape
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      ZONE ONE, └ Pleasure Jams ft. Razor-N-Tape
#     </div>
#     <p class="attending">
#      <span>
#       5
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <a href="/events/1359969">
#     <img height="76" src="/images/events/flyer/2020/1/us-0111-1359969-list.jpg" width="152"/>
#    </a>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1359969" itemprop="url" title="Event details of Shelter 003: Frank &amp; Tony, Jenifa Mayanja">
#       Shelter 003: Frank &amp; Tony, Jenifa Mayanja
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=164270">
#        public records
#       </a>
#      </span>
#     </h1>
#     <div class="grey event-lineup">
#      Frank &amp; Tony, Francis Harris, Anthony Collins, Jenifa Mayanja
#     </div>
#     <p class="attending">
#      <span>
#       18
#      </span>
#      Attending
#     </p>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1358743" itemprop="url" title="Event details of Ambient Church New York: Don Slepian 'Sea of Bliss', Ana Roxanne, JAB">
#       Ambient Church New York: Don Slepian 'Sea of Bliss', Ana Roxanne, JAB
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=141205">
#        Bushwick United Methodist Church
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1365238" itemprop="url" title="Event details of Club Night Club 1 Year Anniversary">
#       Club Night Club 1 Year Anniversary
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=141852">
#        Mood Ring
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366412" itemprop="url" title="Event details of Genesis, The RITHËM Launch Party">
#       Genesis, The RITHËM Launch Party
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=163922">
#        Bar 177
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368666" itemprop="url" title="Event details of Tony Humphries' Le Bain Residency">
#       Tony Humphries' Le Bain Residency
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=36873">
#        Le Bain
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1354629" itemprop="url" title="Event details of The Office presents: RAW Music By: Cry Baby Special Guest">
#       The Office presents: RAW Music By: Cry Baby Special Guest
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        TBA - Brooklyn
#       </span>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1358340" itemprop="url" title="Event details of Sleepy &amp; Boo, Ramza, P.u.r.a - Water Tower Bar - Free">
#       Sleepy &amp; Boo, Ramza, P.u.r.a - Water Tower Bar - Free
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=170772">
#        The Water Tower Bar
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1356053" itemprop="url" title="Event details of Kontravoid, Din, Confines">
#       Kontravoid, Din, Confines
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=75449">
#        Saint Vitus
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1364727" itemprop="url" title="Event details of CLUB CHAI: quest?onmarc 'Phoenix' EP Release Party">
#       CLUB CHAI: quest?onmarc 'Phoenix' EP Release Party
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=71292">
#        Bossa Nova Civic Club
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1357393" itemprop="url" title="Event details of Groundwire with Ashley Oakley, Lethal Trip, Mr.Tipton, Ned Nice, Omo Igi">
#       Groundwire with Ashley Oakley, Lethal Trip, Mr.Tipton, Ned Nice, Omo Igi
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=139960">
#        Elsewhere
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1366350" itemprop="url" title="Event details of The Discount Disco">
#       The Discount Disco
#      </a>
#      <span>
#       at
#       <span class="grey" style="display:inline;">
#        LIC Tonsorial
#       </span>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368173" itemprop="url" title="Event details of Deepbeats // Deep House Yoga">
#       Deepbeats // Deep House Yoga
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=21488">
#        House Of Yes
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li class="">
#   <article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event">
#    <span style="display:none;">
#     <time datetime="2020-01-11T00:00" itemprop="startDate">
#      2020-01-11T00:00
#     </time>
#    </span>
#    <div class="bbox">
#     <h1 class="event-title" itemprop="summary">
#      <a href="/events/1368704" itemprop="url" title="Event details of Court Tree presents: Nicholas Battis, 'Threads'">
#       Court Tree presents: Nicholas Battis, 'Threads'
#      </a>
#      <span>
#       at
#       <a href="/club.aspx?id=49727">
#        Industry City
#       </a>
#      </span>
#     </h1>
#    </div>
#   </article>
#  </li>
#  <li>
#   <div class="but myra mt16" style="width: 152px;">
#    <a href="/submit-event.aspx?ai=8">
#     Submit event
#    </a>
#   </div>
#  </li>
# </ul>

# %%
#Test block for logic. Venues needed special consideration because the containing elements were 
#not consistent between pages, so instead I used the child address of the containing element in
#relation to the parent element which was the h1 header.

dates = [dt.strptime(d.text.strip()[:10],'%Y-%m-%d').strftime("%A %B %d, %Y") for d in events_container.findAll('time')]
titles = [list(t.children)[0].text.strip() for t in events_container.findAll('h1', {'class': "event-title"})]
venues = [list(v.children)[2].text.strip()[3:] for v in events_container.findAll('h1', {'class': "event-title"})]
attends = [int(a.text.strip().split()[0]) for a in events_container.findAll('p', {'class': "attending"})]

print(dates,titles, venues, attends)
# Out:
# ['Sunday January 05, 2020', 'Sunday January 05, 2020', 'Sunday January 05, 2020', 'Sunday January 05, 2020', 'Sunday January 05, 2020', 'Sunday January 05, 2020', 'Monday January 06, 2020', 'Monday January 06, 2020', 'Monday January 06, 2020', 'Monday January 06, 2020', 'Tuesday January 07, 2020', 'Tuesday January 07, 2020', 'Tuesday January 07, 2020', 'Tuesday January 07, 2020', 'Tuesday January 07, 2020', 'Wednesday January 08, 2020', 'Wednesday January 08, 2020', 'Wednesday January 08, 2020', 'Thursday January 09, 2020', 'Thursday January 09, 2020', 'Thursday January 09, 2020', 'Thursday January 09, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Friday January 10, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020', 'Saturday January 11, 2020'] ['Weird Science n.17 with Ron Morelli, L.Sangre, Maroje T', 'Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Funday Brunch Party', 'Zephyr Ann Bday with Paul Nickerson, Ivan Monegro, Mo Yasin', 'Sunday Soiree: Tony Paniro and HŸPNØTÏX', 'The Office presents: Anti-Social Takeover', 'Cotton / Motiv-A / Extol / January', 'The Office presents: Shhh Music By: Mike Nervous', 'Fermented Frequency', 'Industry Night with Special Guests', 'Jamais Vu presents Sheepshead, Feverdream, Serrian', 'Despacito with Dynoman, The Space Wanderer & Amelia Holt', 'Dumbtrax with Brian Best, Mike Terra, Zeni Karpuzi', 'Tuesday Tropical: K.Mal Nite with Disco Bogotá + Feel Free NYC', 'Feel Real presents Good Music Tuesdays', 'Tournament Tuesdays with Trash Panda Qc (DJ Set)', 'Ūndisxile - Sebjara Juancep / Batuz / Mark Dumitrescu', 'Distrikt1 with Melania, Renata', 'Effervescence // Chung, Comfort Zone, Play DJ, Downloadable Content', "Darker Than Wax with Lefto Plus Tonight's Special with Bosq", 'Deep Root Sessions At Public Arts with Mighty Mouse', 'Gusto_invites with Simon Heyliger, Nick Rodrigues', 'Penthouse Edits Vol. 2 Release Party', 'Friday: Working Women and DJ Marcelle', 'Planetarium', 'Robag Wruhme (All Night)', "The Selectors present Taimur's Birthday Bash with Luca Lozano (Klasse Wrecks)", 'The Knocks and Friends Featuring: Mat Zo and The Knocks (DJ Set)', 'Veronica Vasicka / Hieroglyphic Being Live / John Barera', 'HARDER SPRKLBB Bill Sanders (Berlin)', 'Lost Soul Enterprises 8th Anniversary with December (Live), Mozhgan, Emma DJ, Enrique (Live)', 'Nails & Wax presents: Reka and Roman', 'Access presents Drumcell: Luis Flores: Deraout: Mike Melidosian', 'Fomo 5 Year Anniversary with Eli Escobar, Darling Chuck, Sunny Cheeba & More', 'Pandamonium Journeys: Greg Downey', 'Easy with Wilki, Jordan James & Isa', 'The Office presents: Red Light Secrets Music By: Essi', 'The Assembly with AG, Ducci, Tone Troy', 'Dreamland presents Oveous', 'Fist with Perc / Baby Blue / Word of Command / DJ Clone', 'The Carry Nation January 2020', 'Juan Maclean (DJ Set), Solar, Ash Lauryn', 'Saturday: Umfang and OK Williams', 'The Scene: One Year Anniversary', 'Studio 34 with Greg Paulus, Pjay, Gio Gulez, 34th Street John', 'Pleasure Jams feat. Razor-N-Tape', 'Shelter 003: Frank & Tony, Jenifa Mayanja', "Ambient Church New York: Don Slepian 'Sea of Bliss', Ana Roxanne, JAB ...

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def scrape_events(events_page_url):
    #Get html and soup object:
    html = requests.get(events_page_url)
    soup = BeautifulSoup(html.content, 'html.parser')
    
    #Establish aggregate list for event information:
    info_list = []
    
    #Select proper container:
    events_container = soup.find('ul', {'id':"items"})
    
    #Parse info for events:
    dates = [dt.strptime(d.text.strip()[:10],'%Y-%m-%d').strftime("%A %B %d, %Y") for d in events_container.findAll('time')]
    titles = [list(t.children)[0].text.strip() for t in events_container.findAll('h1', {'class': "event-title"})]
    venues = [list(v.children)[2].text.strip()[3:] for v in events_container.findAll('h1', {'class': "event-title"})]
    attends = [int(a.text.strip().split()[0]) for a in events_container.findAll('p', {'class': "attending"})]
    
    info_list = [titles, dates, attends, venues]
        
    df = pd.DataFrame(info_list).transpose()
    df.columns = ["Event_Name", "Event_Date", "Number_of_Attendees", "Venue"]
    return df

# %%
scrape_events(url)
# Out:
#                                            Event_Name  \
# 0   Weird Science n.17 with Ron Morelli, L.Sangre,...
# 1   Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Fund...
# 2   Zephyr Ann Bday with Paul Nickerson, Ivan Mone...
# 3             Sunday Soiree: Tony Paniro and HŸPNØTÏX
# 4           The Office presents: Anti-Social Takeover
# 5                  Cotton / Motiv-A / Extol / January
# 6    The Office presents: Shhh Music By: Mike Nervous
# 7                                 Fermented Frequency
# 8                  Industry Night with Special Guests
# 9   Jamais Vu presents Sheepshead, Feverdream, Ser...
# 10  Despacito with Dynoman, The Space Wanderer & A...
# 11  Dumbtrax with Brian Best, Mike Terra, Zeni Kar...
# 12  Tuesday Tropical: K.Mal Nite with Disco Bogotá...
# 13             Feel Real presents Good Music Tuesdays
# 14   Tournament Tuesdays with Trash Panda Qc (DJ Set)
# 15  Ūndisxile - Sebjara Juancep / Batuz / Mark Dum...
# 16                     Distrikt1 with Melania, Renata
# 17  Effervescence // Chung, Comfort Zone, Play DJ,...
# 18  Darker Than Wax with Lefto Plus Tonight's Spec...
# 19  Deep Root Sessions At Public Arts with Mighty ...
# 20  Gusto_invites with Simon Heyliger, Nick Rodrigues
# 21               Penthouse Edits Vol. 2 Release Party
# 22              Friday: Working Women and DJ Marcelle
# 23                                        Planetarium
# 24                           Robag Wruhme (All Night)
# 25  The Selectors present Taimur's Birthday Bash w...
# 26  The Knocks and Friends Featuring: Mat Zo and T...
# 27  Veronica Vasicka / Hieroglyphic Being Live / J...
# 28               HARDER SPRKLBB Bill Sanders (Berlin)
# 29  Lost Soul Enterprises 8th Anniversary with Dec...
# 30               Nails & Wax presents: Reka and Roman
# 31  Access presents Drumcell: Luis Flores: Deraout...
# 32  Fomo 5 Year Anniversary with Eli Escobar, Darl...
# 33                  Pandamonium Journeys: Greg Downey
# 34                Easy with Wilki, Jordan James & Isa
# 35  The Office presents: Red Light Secrets Music B...
# 36             The Assembly with AG, Ducci, Tone Troy
# 37                          Dreamland presents Oveous
# 38  Fist with Perc / Baby Blue / Word of Command /...
# 39                      The Carry Nation January 2020
# 40           Juan Maclean (DJ Set), Solar, Ash Lauryn
# 41                   Saturday: Umfang and OK Williams
# 42                    The Scene: One Year Anniversary
# 43  Studio 34 with Greg Paulus, Pjay, Gio Gulez, 3...
# 44                   Pleasure Jams feat. Razor-N-Tape
# 45          Shelter 003: Frank & Tony, Jenifa Mayanja
# 46  Ambient Church New York: Don Slepian 'Sea of B...
# 47                 Club Night Club 1 Year Anniversary
# 48                   Genesis, The RITHËM Launch Party
# 49                  Tony Humphries' Le Bain Residency
# 50  The Office presents: RAW Music By: Cry Baby Sp...
# 51  Sleepy & Boo, Ramza, P.u.r.a - Water Tower Bar...
# 52                          Kontravoid, Din, Confines
# 53  CLUB CHAI: quest?onmarc 'Phoenix' EP Release P...
# 54  Groundwire with Ashley Oakley, Lethal Trip, Mr...
# 55                                 The Discount Disco
# 56                       Deepbeats // Deep House Yoga
# 57    Court Tree presents: Nicholas Battis, 'Threads'
#
#                     Event_Date Number_of_Attendees  \
# 0      Sunday January 05, 2020                  49
# 1      Sunday January 05, 2020                   1
# 2      Sunday January 05, 2020                   8
# 3      Sunday January 05, 2020                   8
# 4      Sunday January 05, 2020                   4
# 5      Sunday January 05, 2020                   3
# 6      Monday January 06, 2020                   1
# 7      Monday January 06, 2020                   1
# 8      Monday January 06, 2020                   8
# 9      Monday January 06, 2020                   7
# 10    Tuesday January 07, 2020                   2
# 11    Tuesday January 07, 2020                   1
# 12    Tuesday January 07, 2020                   6
# 13    Tuesday January 07, 2020                   6
# 14    Tuesday January 07, 2020                   4
# 15  Wednesday January 08, 2020                   9
# 16  Wednesday January 08, 2020                   2
# 17  Wednesday January 08, 2020                   7
# 18   Thursday January 09, 2020                   1
# 19   Thursday January 09, 2020                 100
# 20   Thursday January 09, 2020                  73
# 21   Thursday January 09, 2020                  64
# 22     Friday January 10, 2020                  55
# 23     Friday January 10, 2020                  42
# 24     Friday January 10, 2020                  33
# 25     Friday January 10, 2020                  32
# 26     Friday January 10, 2020                  28
# 27     Friday January 10, 2020                  94
# 28     Friday January 10, 2020                  41
# 29     Friday January 10, 2020                  26
# 30     Friday January 10, 2020                  25
# 31     Friday January 10, 2020                   6
# 32     Friday January 10, 2020                   6
# 33     Friday January 10, 2020                   5
# 34     Friday January 10, 2020                  18
# 35     Friday January 10, 2020                None
# 36     Friday January 10, 2020                None
# 37     Friday January 10, 2020                None
# 38   Saturday January 11, 2020                None
# 39   Saturday January 11, 2020                None
# 40   Saturday January 11, 2020                None
# 41   Saturday January 11, 2020                None
# 42   Saturday January 11, 2020                None
# 43   Saturday January 11, 2020                None
# 44   Saturday January 11, 2020                None
# 45   Saturday January 11, 2020                None
# 46   Saturday January 11, 2020                None
# 47   Saturday January 11, 2020                None
# 48   Saturday January 11, 2020                None
# 49   Saturday January 11, 2020                None
# 50   Saturday January 11, 2020                None
# 51   Saturday January 11, 2020                None
# 52   Saturday January 11, 2020                None
# 53   Saturday January 11, 2020                None
# 54   Saturday January 11, 2020                None
# 55   Saturday January 11, 2020                None
# 56   Saturday January 11, 2020                None
# 57   Saturday January 11, 2020                None
#
#                                Venue
# 0                        Magick City
# 1                         Taj Lounge
# 2                     public records
# 3                       TBA Brooklyn
# 4                     TBA - Brooklyn
# 5              Bossa Nova Civic Club
# 6                     TBA - Brooklyn
# 7              Bossa Nova Civic Club
# 8                          Rose Gold
# 9                      Jupiter Disco
# 10                     Jupiter Disco
# 11                      TBA Brooklyn
# 12                        Kinfolk 90
# 13                       Rumpus Room
# 14                       Wonderville
# 15                      TBA Brooklyn
# 16             Bossa Nova Civic Club
# 17                         Mood Ring
# 18                         Good Room
# 19                       Public Arts
# 20                      TBA Brooklyn
# 21                         Mood Ring
# 22                          Nowadays
# 23                    TBA - Brooklyn
# 24      Lost Circus at Avant Gardner
# 25                    public records
# 26                         Elsewhere
# 27                          BASEMENT
# 28                     3 Dollar Bill
# 29                         Good Room
# 30                   The Sultan Room
# 31                           Quantum
# 32                         Elsewhere
# 33                      Bogart House
# 34                           Le Bain
# 35                    TBA - Brooklyn
# 36                         Elsewhere
# 37     Good Behavior (at MADE Hotel)
# 38                          BASEMENT
# 39                         Good Room
# 40                         Elsewhere
# 41                          Nowadays
# 42                              Eris
# 43                      TBA Brooklyn
# 44                         Elsewhere
# 45                    public records
# 46  Bushwick United Methodist Church
# 47                         Mood Ring
# 48                           Bar 177
# 49                           Le Bain
# 50                    TBA - Brooklyn
# 51               The Water Tower Bar
# 52                       Saint Vitus
# 53             Bossa Nova Civic Club
# 54                         Elsewhere
# 55                     LIC Tonsorial
# 56                      House Of Yes
# 57                     Industry City

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Get html and soup object:
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    
    #Get the url, if there is no url_container break function:
    url_container = soup.find('li', {'id':"liNext", 'class':"but arrow-right right"})
    if url_container:
        url_suffix = url_container.find('a').attrs['href']
    else:
        return None
    next_page_url = 'https://residentadvisor.net{}'.format(url_suffix)
    
    return next_page_url

# %%
#Test to see if there are errors when last page is reached:
next_page('https://www.residentadvisor.net/events/us/virginia/week/2020-01-11')

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#There are not 1000 events listed, I'll scrape all they have.
next_url = 'https://residentadvisor.net/events/us/newyork'
df = pd.DataFrame()

while next_url:
    temp_df = scrape_events(next_url)
    df = pd.concat([df, temp_df], axis=0)
    next_url = next_page(next_url)

df.head(20)
# Out:
#                                            Event_Name  \
# 0   Weird Science n.17 with Ron Morelli, L.Sangre,...
# 1   Taj Lounge NYC Hip Hop vs. Reggae™ Sunday Fund...
# 2   Zephyr Ann Bday with Paul Nickerson, Ivan Mone...
# 3             Sunday Soiree: Tony Paniro and HŸPNØTÏX
# 4           The Office presents: Anti-Social Takeover
# 5                  Cotton / Motiv-A / Extol / January
# 6    The Office presents: Shhh Music By: Mike Nervous
# 7                                 Fermented Frequency
# 8                  Industry Night with Special Guests
# 9   Jamais Vu presents Sheepshead, Feverdream, Ser...
# 10  Despacito with Dynoman, The Space Wanderer & A...
# 11  Dumbtrax with Brian Best, Mike Terra, Zeni Kar...
# 12  Tuesday Tropical: K.Mal Nite with Disco Bogotá...
# 13             Feel Real presents Good Music Tuesdays
# 14   Tournament Tuesdays with Trash Panda Qc (DJ Set)
# 15  Ūndisxile - Sebjara Juancep / Batuz / Mark Dum...
# 16                     Distrikt1 with Melania, Renata
# 17  Effervescence // Chung, Comfort Zone, Play DJ,...
# 18  Darker Than Wax with Lefto Plus Tonight's Spec...
# 19  Deep Root Sessions At Public Arts with Mighty ...
#
#                     Event_Date Number_of_Attendees                  Venue
# 0      Sunday January 05, 2020                  49            Magick City
# 1      Sunday January 05, 2020                   1             Taj Lounge
# 2      Sunday January 05, 2020                   8         public records
# 3      Sunday January 05, 2020                   8           TBA Brooklyn
# 4      Sunday January 05, 2020                   4         TBA - Brooklyn
# 5      Sunday January 05, 2020                   3  Bossa Nova Civic Club
# 6      Monday January 06, 2020                   1         TBA - Brooklyn
# 7      Monday January 06, 2020                   1  Bossa Nova Civic Club
# 8      Monday January 06, 2020                   8              Rose Gold
# 9      Monday January 06, 2020                   7          Jupiter Disco
# 10    Tuesday January 07, 2020                   2          Jupiter Disco
# 11    Tuesday January 07, 2020                   1           TBA Brooklyn
# 12    Tuesday January 07, 2020                   6             Kinfolk 90
# 13    Tuesday January 07, 2020                   6            Rumpus Room
# 14    Tuesday January 07, 2020                   4            Wonderville
# 15  Wednesday January 08, 2020                   9           TBA Brooklyn
# 16  Wednesday January 08, 2020                   2  Bossa Nova Civic Club
# 17  Wednesday January 08, 2020                   7              Mood Ring
# 18   Thursday January 09, 2020                   1              Good Room
# 19   Thursday January 09, 2020                 100            Public Arts

# %%
print(len(df))
# Out:
# 284

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
